# %% [markdown]
# # Calibration

# %% [markdown]
# `calibration` is a fucntion which shows you type of calibration and plots your calibration based on EDF file and also show details of calibration.

# %%
import etformat as et
et.calibration(r"D:\Github_web_page_website\test.EDF")
# Out:
# 📖 etformat 1.1.1 - For Documentation, visit: https://ahsankhodami.github.io/etformat/intro.html
# 📌 Eye: RIGHT
# 📌 Number of calibrations: 1
# 📌 Calibration Model: HV5
# 📌 Average Error: 0.15 degrees
# 📌 Max Error: 0.3 degrees
